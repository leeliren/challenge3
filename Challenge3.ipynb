# %%
'''
Guess the number game.
The computer selects a random number between 1 and 100.
The user keeps guessing which number the computer has chosen
until they get it right.
The computer responds 'bingo!' or 'too high' or 'too low' after
each guess.
After the user has guessed the number correctly the computer output
how many attempts it has made.
'''
import random 
number = random.randint(1,100)
attempts = 0
while True:
    guess = int(input("Enter guess: "))
    if guess != number:
        attempts+=1
        if guess < number:
            print("too low")
        elif guess >number:
            print("too high")
    else:
        print("bingo! you've made ", attempts, " attempts.")
        break
# Out:
# Enter guess: 30
# too low
# Enter guess: 50
# too low
# Enter guess: 80
# too low
# Enter guess: 99
# too high
# Enter guess: 89
# too high
# Enter guess: 85
# too low
# Enter guess: 87
# too high
# Enter guess: 86
# bingo! you've made  7  attempts.

# %%
'''
Reverse the above game. You think of a number. Get the
computer to guess a number and you respond with too high(H),
too low(L) or bingo!(B). Make sure the computer has a game
plan - don't just let it guess at random!
'''
def guess(low, high):
    mid = (low+high)//2
    print("is it", mid, "?")
    ans = input("H/L/B: ")
    if ans!= "B":
        if ans == "L":
            guess(low,mid-1)
        elif ans == "H":
            guess(mid+1,high)
    else:
        print(mid)
print("think of a number between 1~100....")
guess(1,100)
# Out:
# think of a number between 1~100....
# is it 50 ?
# H/L/B: L
# is it 25 ?
# H/L/B: L
# is it 12 ?
# H/L/B: H
# is it 18 ?
# H/L/B: H
# is it 21 ?
# H/L/B: H
# is it 23 ?
# H/L/B: L
# is it 22 ?
# H/L/B: B
# 22

# %%
'''
Write a function that will convert a mark into a grade.
The function will return 'A', 'B', 'C', 'D', 'E', 'S' or 'U'.
The function will require a parameter mark.
The formula is >=70% â> 'A', >=60% â>'B', >=55% â> 'C',
>=50% â> 'D', >=45% â>'E', >=40% â> 'S', <40% â> 'U'.
Assume the maximum mark is 100.
Having written the function we want to use it three times.
Write a program with the function that allows the user to enter
two module marks and displays the grade. It then computes the
average and displays the overall grade. E.g.

Enter Module 1 mark: 68
Enter Module 2 mark: 57
Result
Module 1: B
Module 2: C
Overall: B 
'''
m1 = int(input("Enter Module 1 mark: "))
m2 = int(input("Enter Module 2 mark: "))
def grade(marks):
    if marks>=70:
        return "A"
    elif marks<70 and marks>=60:
        return "B"
    elif marks <60 and marks>=55:
        return "C"
    elif marks <55 and marks>=50:
        return "D"
    elif marks <50 and marks>=45:
        return "E"
    elif marks <45 and marks>=40:
        return "S"
    elif marks <40 and marks>=0:
        return "U"
    else:
        return "Marks out of range!"
def average(m1, m2):
    return (m1+m2)//2
print("result")
print("Module 1: ", grade(m1))
print("Module 2: ", grade(m2))
print("Overall: ", grade(average(m1,m2)))
# Out:
# Enter Module 1 mark: 47
# Enter Module 2 mark: 55
# result
# Module 1:  E
# Module 2:  C
# Overall:  D

# %%
'''
For the above problem, allow a maximum mark other than 100.
This will require the user to enter both the mark and maximum possible for that module.
The function will also require the maximum mark in order to calculate
the grade so another parameter will be needed. 
'''
m1 = int(input("Enter Module 1 mark: "))
max1 = int(input("Enter Module 1 max: "))
percent1 = int(((m1/max1)*100)//1)
m2 = int(input("Enter Module 2 mark: "))
max2 = int(input("Enter Module 2 max: "))
percent2 = int(((m2/max2)*100)//1)
def grade(marks):
    if marks>=70:
        return "A"
    elif marks<70 and marks>=60:
        return "B"
    elif marks <60 and marks>=55:
        return "C"
    elif marks <55 and marks>=50:
        return "D"
    elif marks <50 and marks>=45:
        return "E"
    elif marks <45 and marks>=40:
        return "S"
    elif marks <40 and marks>=0:
        return "U"
    else:
        return "Marks out of range!"

def average(m1, m2):
    return (m1+m2)//2

print("result")
print("Module 1: ", grade(percent1))
print("Module 2: ", grade(percent2))
print("Overall: ", grade(average(percent1,percent2)))
# Out:
# Enter Module 1 mark: 2
# Enter Module 1 max: 11
# Enter Module 2 mark: 10
# Enter Module 2 max: 15
# result
# Module 1:  U
# Module 2:  B
# Overall:  S

# %%
'''
Write a procedure draw_stars that will draw a sequence of spaces followed by a sequence of stars.
It should accept two parameters - the number of spaces and the number of stars. E.g

draw_stars(3,5) would produce
___***** ( _ indicates a space)

Use your procedure to draw

  ***
  ***
   *
  ***
*******
  ***
  * *
 ** ** 
'''

def draw(spaces,stars):
    return spaces*" "+ stars*"*" 

print(draw(2,3))
print(draw(2,3))
print(draw(3,1))
print(draw(2,3))
print(draw(0,7))
print(draw(2,3))
print(draw(2,1), draw(0,1))
print(draw(1,2),draw(0,2))
# Out:
#   ***
#   ***
#    *
#   ***
# *******
#   ***
#   * *
#  ** **

# %%
'''
Write a program using the above draw_stars procedure that will draw a pyramid
whose base is a width specified by the user. E.g.

Enter base: 5
  *
 ***
*****

Assume base is an odd number. 
'''
def draw(base):
    levels = (base//2)+1
    for i in range (0,levels):
        
        stars = i*2+1
        spaces = base-stars
        print((spaces//2)*' ', stars*"*", spaces//2*' ')
draw(91)
# Out:
#                                               *
#                                              ***
#                                             *****
#                                            *******
#                                           *********
#                                          ***********
#                                         *************
#                                        ***************
#                                       *****************
#                                      *******************
#                                     *********************
#                                    ***********************
#                                   *************************
#                                  ***************************
#                                 *****************************
#                                *******************************
#                               *********************************
#                              ***********************************
#                             *************************************
#                            ***************************************
#                           *****************************************
#                          *******************************************
#                         *********************************************
#                        ***********************************************
#                       *************************************************
#                      ***************************************************
#                     *****************************************************
#                    *******************************************************
#                   *********************************************************
#                  ***********************************************************
#                 *************************************************************
#                ***************************************************************
#               *****************************************************************
#              *******************************************************************
#             *********************************************************************
#            ***********************************************************************
#           *************************************************************************
#          ***************************************************************************
#         *****************************************************************************
#        *******************************************************************************
#       *********************************************************************************
#      ***********************************************************************************
#     *************************************************************************************
#    ***************************************************************************************
#   *****************************************************************************************
#  *******************************************************************************************

# %%
'''
Write a program to perform a basic encryption and decryption on text.
This algorithm works by moving letters along by an offset. 
If the offset is 2 then b â> d, h â> j, etc.
Write two functions - encrypt and decrypt. Both will return a string.
The user selects whether to encrypt or decrypt.
The user enters sentence to encrypt and the offset.
The program responds with the encrypted or decrypted version. 
'''



def encrypt(str_en, off_en):
    for i in str_en:
        new_ord_en = ord(i)+off_en
        new_en = print(chr(new_ord_en), end="")

def decrypt(str_de, off_de):
    for i in str_de:
        new_ord_de = ord(i)-off_de
        new_en = print(chr(new_ord_de), end="")

start = input("Encrypt or decrypt?: ")
if start == "encrypt":
    str_en = input("enter your string: ")
    off_en = int(input("enter offset: "))
    encrypt(str_en, off_en)
elif start == "decrypt":
    str_de = input("enter your string: ")
    off_de = int(input("enter offset: "))
    decrypt(str_de, off_de)
# Out:
# Encrypt or decrypt?: encrypt
# enter your string: computingA
# enter offset: 4
# gsqtyxmrkE

# %%
'''
The above algorithm is actually easy to crack. A much better algorithm 
would be one that has a different offset for every letter. 
We can do this using the random number generator - because it generates 
the same sequence of random numbers from a 'seed' position. As long as
sender and receiver agree where to 'seed' (this will be the encryption
key) they can both work out the same offsets. 

Algorithm for encrypt function

function Encrypt(text, key)
  Randomize(key)
  For each letter in text
    Get its ascii code
    Add random offset int(rnd()*10) to ascii code
    Turn this new ascii code back to a character
    Append character to ciphertext string
  Endfor
  return ciphertext
end
'''
from random import randint, seed 

def encrypt(text, key):
    seed(a=key)
    for i in text:
        num = ord(i)
        num+=randint(0,10)
        print(chr(num),end="")
encrypt("heellooo",1)
# Out:
# jnfpmvvv

# %%
'''
For the above task, use a single function with an extra parameter to indicate
whether the text is being encrypted or decrypted rather than having two 
different functions.
'''
def ende(text,key,start):
    seed(a=key)
    for i in text:
        if start == "encrypt":
            num = ord(i)
            num+=randint(0,10)
            print(chr(num),end="")
        elif start == "decrypt":
            num1 = ord(i)
            num1-=randint(0,10)
            print(chr(num1),end="")
ende("done",1,"encrypt")
print()
ende("fxoi",1,"decrypt")
# Out:
# fxoi
# done
